# %%
import seaborn as sns
import pandas as ps
import matplotlib.pyplot as pt
data={'Days':[1,2,3,4,5],
      'NOP':[34,89,12,22,19]}
df=ps.DataFrame(data)
print(df)

sns.lineplot(data=data,x='Days',y='NOP')
pt.show()
# Out:
#    Days  NOP
# 0     1   34
# 1     2   89
# 2     3   12
# 3     4   22
# 4     5   19

# %%
import matplotlib.pyplot as pt
import pandas as ps
import numpy as np
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)


color=sns.color_palette('hls',8)

sns.lineplot(data=data,x='VERIFICATION_STATUS' ,y='INSTALLMENT',hue='TERM',palette=color)# shownsize lines 

pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import numpy as np
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)


color=sns.color_palette('husl',8)

sns.lineplot(data=data,x='VERIFICATION_STATUS' ,y='INSTALLMENT',hue='TERM',palette=color)# shownsize lines 

pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import numpy as np
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)


color=sns.color_palette('Paired')

sns.lineplot(data=data,x='VERIFICATION_STATUS' ,y='INSTALLMENT',hue='TERM',palette=color)# shownsize lines 

pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import numpy as np
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)


color=sns.color_palette('tab10')

sns.lineplot(data=data,x='VERIFICATION_STATUS' ,y='INSTALLMENT',hue='TERM',palette=color)# shownsize lines 

pt.show()

#jitna value utna color
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import numpy as np
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)


color=sns.color_palette('viridis')

sns.lineplot(data=data,x='VERIFICATION_STATUS' ,y='INSTALLMENT',hue='TERM',palette=color)# shownsize lines 

pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import numpy as np
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)


color=sns.color_palette('GnBu')

sns.lineplot(data=data,x='VERIFICATION_STATUS' ,y='INSTALLMENT',hue='TERM',palette=color)# shownsize lines 

pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
#SCATTER PLOt
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')#if want sample data tu load data base,or excel ka data ka leyai read karai ga(jo already hoga apka ps data) 
print(data)
#no to no relationship dehk sehkthai hain scatterplot ma
sns.scatterplot(data=data,x='total_bill',y='tip',hue='smoker' )
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')#if want sample data tu load data base,or excel ka data ka leyai read karai ga(jo already hoga apka ps data) 
print(data)
#num to num relationship dehk sehkthai hain scatterplot ma
sns.scatterplot(data=data,x='total_bill',y='tip',hue='day' )
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')#if want sample data tu load data base,or excel ka data ka leyai read karai ga(jo already hoga apka ps data) 
print(data)
#no to no relationship dehk sehkthai hain scatterplot ma
sns.scatterplot(data=data,x='total_bill',y='tip',hue='smoker',size='size',marker='s')#size represent no of people
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)
sns.scatterplot(data=df,x='PAYMENT',y='INSTALLMENT',hue='INT_RATE')
pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
#BAR PLOT
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')#if want sample data tu load data base,or excel ka data ka leyai read karai ga(jo already hoga apka ps data) 
print(data)
sns.barplot(data=data,x='day',y='tip',estimator='median' ,hue='sex',palette='viridis',order=['Sun','Sat','Fri','Thurs'])
pt.plot()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# []

# %%
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')#if want sample data tu load data base,or excel ka data ka leyai read karai ga(jo already hoga apka ps data) 
print(data)
#if you doesn't want to error bar tu use that jo line ha na wo haat jai gi
sns.barplot(data=data,x='day',y='tip',estimator='median' ,hue='sex',order=['Sun','Sat','Fri','Thurs'],errorbar=('ci', 0))
pt.plot()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# []

# %%
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')#if want sample data tu load data base,or excel ka data ka leyai read karai ga(jo already hoga apka ps data) 
print(data)
sns.barplot(data=data,x='day',y='tip',estimator='median' ,hue='sex',palette='viridis',order=['Mon','Tues','Wed','Thurs'])
pt.plot()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# []

# %%
#HISTOGRAM
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')
sns.histplot(data,x='day',hue='sex',kde=True)
pt.show()

# %%
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('titanic')
print(data)
sns.histplot(data=data,x='age',hue='who',kde=True)
pt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('titanic')
print(data)
sns.histplot(data=data,x='age',hue='who',kde=True,discrete=True)#space km ai ga apas ma
pt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#HeatMAP
#numeric value mai create hota
import matplotlib.pyplot as pt
import seaborn as sns

data=sns.load_dataset('tips')
print(data)
gp=data.groupby('day').agg({'tip':'mean'})
sns.heatmap(gp)
pt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)
gp=df.groupby('VERIFICATION_STATUS').agg({'PAYMENT':'mean'})
sns.heatmap(gp)
pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
#COUNT PLOT
#no of count any value

import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
print(data)
color=['red','blue']
sns.countplot(data=data,x='sex',palette=color)
pt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1020\2841645881.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
print(data)

sns.countplot(data=data,x='day',palette='tab10')
pt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1020\1734469891.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)

sns.countplot(data=df,x='INSTALLMENT')
pt.xlabel('INSTALLMENT',fontzie=9)#16;52 ma
pt.show()
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)

sns.countplot(data=df,x='INSTALLMENT',hue='LOAN_STATUS',palette='GnBu')

pt.show()

# %%
#VIOLIN PLOT
#when we see statistical data where our mean , median value is kisi bhi point pr kitna frequency of data nikal kar a raha ha only used on the numeric value
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.violinplot(data=data,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.violinplot(data=data,x='tip')
# Out:
# <Axes: xlabel='tip'>

# %%
data=ps.read_excel('Umama text pandas file.xlsx')
df=ps.DataFrame(data)
print(df)
sns.violinplot(data=df,x='PAYMENT')
# Out:
#          TERM VERIFICATION_STATUS  ANNUAL_INCOME     DTI  INSTALLMENT  \
# 0   60 months     Source Verified        30000.0  0.0100        59.83
# 1   36 months     Source Verified        48000.0  0.0535       109.43
# 2   36 months        Not Verified        50000.0  0.2088       421.65
# 3   60 months     Source Verified            NaN  0.0540        97.06
# 4   36 months            Verified        83000.0  0.0231       106.53
# 5   36 months        Not Verified        28000.0  0.1260       275.96
# 6   36 months            Verified        94800.0  0.2453       205.86
# 7   36 months     Source Verified        59000.0  0.0665       172.10
# 8   36 months            Verified       116400.0  0.0394       762.08
# 9   60 months        Not Verified        36000.0  0.1773        93.21
#
#    INT_RATE  LOAN AMOUNT  TOTAL ACCOUNT  PAYMENT  LOAN_STATUS
# 0    0.1527      2500.00            4.0     1009   Fully Paid
# 1    0.1864         0.00            NaN     3939  Charged Off
# ...

# %%
#PAIR PLOT
#no need to pass axis
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.pairplot(data)
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.pairplot(data,hue='day')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('iris')
sns.pairplot(data)
pt.show()

# %%
#STRIP PLOT
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
#we use dodge for separate the things 
sns.stripplot(data=data,x='day',y='total_bill',hue='sex',dodge=True)
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
#we use jitter for the purpose of shifting 
sns.stripplot(data=data,x='day',y='total_bill',hue='sex',dodge=True,jitter=0.4)
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.stripplot(data=data,x='day',y='total_bill',hue='sex')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.scatterplot(data=data,x='tip',y='total_bill')
pt.show()

# %%
#BOX PLOT
#mean ka kitna as pas data ha ,kitna outliner hain then we use this 
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.boxplot(data=data,x='tip',y='sex')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
#if we use orient then you should take numeric value on y axis 
sns.boxplot(data=data,x='sex',y='tip',orient='vertical')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
color=['brown','yellow','purple','green']
#if we use orient then you should take numeric value on y axis 
sns.boxplot(data=data,x='day',y='tip',orient='vertical',palette=color,fliersize=9)#for the shape of outlayer
pt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1020\430941444.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data,x='day',y='tip',orient='vertical',palette=color,fliersize=9)#for the shape of outlayer

# %%
#CATEGoREcAL PLOT
#cat plot stands for CATEGoREcAL PLOT
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.catplot(data=data,x='day',y='tip')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.catplot(data=data,x='day',y='tip',kind='violin')
pt.show()

# %%
#STYLE AND COLOR IN PLOT
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('exercise')
sns.set_style(style='darkgrid')
sns.barplot(data=data, x='time',y='pulse')
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('exercise')
sns.set_style(style='whitegrid')
sns.barplot(data=data, x='time',y='pulse')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('exercise')
sns.set_style(style='ticks')#ticks enable karna ha tu use that nichai sa bhi a gaei hain line
sns.barplot(data=data, x='time',y='pulse')
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

sns.palplot(sns.color_palette())
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

sns.palplot(sns.color_palette('viridis',4))
pt.show()

# %%
import matplotlib.pyplot as pt
import seaborn as sns

sns.palplot(sns.color_palette('spring'))
pt.show()

# %%
#MUTIPLE PLOTS
#ek he data sa ek hee plot ma use karna ha multiple plot tu use that
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
a=sns.FacetGrid(data,col='day')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
a=sns.FacetGrid(data,col='day',height=6)
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
a=sns.FacetGrid(data,col='smoker')
a.map(sns.barplot,'day','tip')
pt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#RELATIONAL PLOT 
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.relplot(data=data,x='tip',y='total_bill',hue='smoker')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.relplot(data=data,x='tip',y='total_bill',hue='smoker',kind='line')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.relplot(data=data,x='tip',y='total_bill',hue='smoker',col='day',size='smoker')
pt.show()

# %%
#SWARM PLOT
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.swarmplot(data=data,x='day',y='total_bill',hue='sex',dodge=True)# if it is in the strip plot the data is overlap but in by default in this not overlap
pt.show()

# %%
#KDE(kernai density estination) PLOT
#create wave and show our data
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.kdeplot(data=data,x='total_bill',hue='sex')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.kdeplot(data=data,x='total_bill')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')
sns.kdeplot(data=data,x='total_bill',hue='day')
pt.show()

# %%
import matplotlib.pyplot as pt
import pandas as ps
import seaborn as sns

data=sns.load_dataset('tips')

sns.kdeplot(data=data,x='total_bill',hue='day',multiple='stack')
pt.show()

# %%
palette=['pink','black','yellow','orange']
sns.kdeplot(data=data,x='total_bill',hue='day',multiple='fill',palette=color)
pt.show()
